# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from tabulate import tabulate
import re
import os
import math

# %% [markdown]
# ## Start here
# First, we query `papyri.info` for all Dura papyri with images. Then we scrape some initial data from the search results, including the papyri.info URLs.

# %%
# URL to query all papyri from Dura-Europos with images present
QUERY_URL = "https://papyri.info/search?INT=on&EXT=on&PLACE=Dura+-+Europos&DOCS_PER_PAGE=1000"

page = requests.get(QUERY_URL).text
soup = BeautifulSoup(page, 'html.parser')

def parseResultRow(r):
    url = r.find("a").get("href")
    url = "https://papyri.info" + url.split("?")[0]
    
    main_identifier = r.find("td", class_="identifier").text
    
    other_identifiers = [] 
    for o in r.find("td", class_="identifier").get("title").split("="):
        if len(o.strip()):
            other_identifiers.append(o.strip())
    
    title = r.find("div", class_="title-long").text
    
    location = r.find("td", class_="display-place").text
    date = r.find("td", class_="display-date").text    
    languages = r.find("td", class_="language").text.strip()
    return {
        "Papyri.info URL": url,
        "Main identifier": main_identifier,
        "Other identifiers": ",".join(other_identifiers),
        "Title": title,
        "Location": location,
        "Date": date,
        "Languages": languages,
    }


result_rows = soup.find_all("tr", class_="result-record")
row_dicts = [parseResultRow(r) for r in result_rows]

# %%
table = []
table.append(list(row_dicts[0].keys()))
for r in row_dicts:
    table.append(r.values())
tabulate(table[1:], table[0], tablefmt='html')
# Out:
# '<table>\n<thead>\n<tr><th>Papyri.info URL                            </th><th>Main identifier  </th><th>Other identifiers                                             </th><th>Title                                                            </th><th>Location      </th><th>Date           </th><th>Languages         </th></tr>\n</thead>\n<tbody>\n<tr><td>https://papyri.info/ddbdp/basp;56;100      </td><td>basp 56 100      </td><td>BASP 56                                                       </td><td>Roster?                                                          </td><td>Dura - Europos</td><td>200 CE - 230 CE</td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;310       </td><td>chla 6 310       </td><td>P.Dura 55,P.CtYBR inv. DP 105 qua,yale 4401050000             </td><td>File of Letters                                                  </td><td>Dura - Europos</td><td>218 CE - 220 CE</td><td>grc,  grc,  la, la</td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;311       </td><td>chla 6 311       </td><td>P.Dura 56,P.CtYBR inv. DP 8 fol,yale 4400080000               </td><td>Letters from Provincial Headquarters, Assigning Mounts           </td><td>Dura - Europos</td><td>208 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;312       </td><td>chla 6 312       </td><td>P.Dura 57,P.CtYBR inv. DP 32,yale 4400320000                  </td><td>Fragment of Letters                                              </td><td>Dura - Europos</td><td>208 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;313       </td><td>chla 6 313       </td><td>P.Dura 58,P.CtYBR inv. DP 63(B) qua,yale 4400634200           </td><td>Copy of Letter Assigning Mounts                                  </td><td>Dura - Europos</td><td>240 CE - 250 CE</td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;314       </td><td>chla 6 314       </td><td>P.Dura 59,P.CtYBR inv. DP 7 qua,yale 4400070000               </td><td>Letter from a Governor of Syria                                  </td><td>Dura - Europos</td><td>241 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;315       </td><td>chla 6 315       </td><td>ChLA 6 315,P.CtYBR inv. DP 4 qua,yale 4400040000              </td><td>Lettres circulaires                                              </td><td>Dura - Europos</td><td>208 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;316       </td><td>chla 6 316       </td><td>ChLA 6 316,P.CtYBR inv. DP 18 qua,yale 4400180000             </td><td>Lettre officielle concernant les «frumentations»                 </td><td>Dura - Europos</td><td>216 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;317       </td><td>chla 6 317       </td><td>P.Dura 62,P.CtYBR inv. DP 33,yale 4400330000                  </td><td>Fragmentary Letter                                               </td><td>Dura - Europos</td><td>216 CE - 220 CE</td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;318       </td><td>chla 6 318       </td><td>P.Dura 63,P.CtYBR inv. DP 10(Second text) qua,yale 4400100032 </td><td>Fragmentary Correspondence                                       </td><td>Dura - Europos</td><td>211 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;319       </td><td>chla 6 319       </td><td>P.Dura 64,P.CtYBR inv. DP 15 qua,yale 4400150000              </td><td>Letters to the Tribune from a Praepositus                        </td><td>Dura - Europos</td><td>221 CE         </td><td>la, la            </td></tr>\n<tr><td>https://papyri.info/ddbdp/chla;6;320       </td><td>chla 6 320       </td><td>P.Dura 65,P.CtYBR inv. DP 23,yale 4400230000                  </td><td>Fragment of Letter                                               </td><td>Dura - Europos</td><td>221 CE       ...

# %% [markdown]
# Now for each record, we try to fetch a Yale library image URL:

# %%
for i in range(len(row_dicts)):
    r = row_dicts[i]
    print("Fetching", r["Papyri.info URL"], "... ", end="", flush=True)
    page = requests.get(r["Papyri.info URL"]).text
    print("done.")
    soup = BeautifulSoup(page, 'html.parser')
    
    apis_data = soup.find("div", class_="apis")
    if not apis_data:
        print("    No Yale APIS listing found. Can we find any images at all? ", end="", flush=True)
        images_hdr = soup.find("th", string="Images")        
        images_url = images_hdr.parent.find("a").get("href")
        r["Image URL"] = images_url
        if (images_hdr):
            print("Yes!")
        else:
            print("No.")
        continue
        
    images_hdr = apis_data.find("th", string="Images")
    images_url = images_hdr.parent.find("a").get("href")
    r["Image URL"] = images_url
    print("    Found APIS image URL.")
# Out:
# Fetching https://papyri.info/ddbdp/basp;56;100 ... done.
#     No Yale APIS listing found. Can we find any images at all? Yes!
# Fetching https://papyri.info/ddbdp/chla;6;310 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;311 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;312 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;313 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;314 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;315 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;316 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;317 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;318 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;319 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;6;320 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;322 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;325 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;326 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;327 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;328 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;329 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;330 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;331 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;332 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;333 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;334 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;335 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;336 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;337 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;338 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;339 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;340 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;341 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;342 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;343 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;344 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;345 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;346 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;347 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;348 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;350 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;351 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;352 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;353 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;7;354 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;8;355 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;8;356 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;357 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;358 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;359 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;361 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;362 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;363 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;364 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;365 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;366 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;367 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;368 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;369 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;370 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;371 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;372 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;373 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;374 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;375 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;376 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;377 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;378 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;379 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;382 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;383 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;384 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;386 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;387 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;388 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;389 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;390 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;391 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;392 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;393 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;394 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/chla;9;395 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;14 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;16 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;18 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;19 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;22 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;24 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;25 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;27 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;28 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;29 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;32 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;34 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;35 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;36 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;37 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;38 ... done.
#     No Yale APIS listing found. Can we find any images at all? Yes!
# Fetching https://papyri.info/ddbdp/p.dura;;39 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;40 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;41 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;42 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;45 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;49 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;51 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;52 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;53 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;59 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;62 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;63 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;65 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;67 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;68 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;69 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;70 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;71 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;72 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;73 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;78 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;82 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;83 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;84 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;85 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;87 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;89 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;98 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;99 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;100 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;101 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;103 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;104 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;111 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;116 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;117 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;118 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;119 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;120 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;121 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;123 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;124 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;125 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;126 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;129 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;132 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;136 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;137 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;141 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;144 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;145 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;146 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;147 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;148 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;149 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/p.dura;;150 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;1 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;2 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;3 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;4 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;6 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;7 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;8 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;12 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;13 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;14 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;15 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;16 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;17 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;18 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;19 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;22 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;23 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;25 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;26 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;27 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;29 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;31 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;32 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;33 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;35 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;41 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;42 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;43 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;44 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;47 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;48 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;49 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;50 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;54 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;55 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;56 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;57 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;60 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;61 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;62 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;66 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;83 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;88 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;91 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;92 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;93 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;94 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;95 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;96 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;97 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;98 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;99 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;100 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;101 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;103 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;104 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;105 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;106 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;107 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;108 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;109 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;110 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;111 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;112 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;113 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;114 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;115 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;116 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;117 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;118 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;119 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;120 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;121 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;122 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;123 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;124 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;125 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;126 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;127 ... done.
#     Found APIS image URL.
# Fetching https://papyri.info/ddbdp/rom.mil.rec;1;128 ... done.
#     Found APIS image URL.

# %% [markdown]
# This will give us (hopefully) a link to the Yale Library listing page for each one. Now we have to go into it and fetch the links to the actual image files.

# %%
for i in range(len(row_dicts)):
    r = row_dicts[i]
    print("Fetching " + r["Image URL"] + " ... ", end = "", flush = True)
    page = requests.get(r["Image URL"]).text
    print("done.")
    soup = BeautifulSoup(page, 'html.parser')
    thumbnails_div = soup.find("div", class_="complexThumbnails")
    if thumbnails_div is not None:
        thumb_URLs = [im.get("src") for im in thumbnails_div.findAll("img")]
        image_URLs = []
        for t in thumb_URLs:
            coll_id = re.search(r"digcoll:[0-9]*/", t).group(0)
            image_URLs.append("https://imageserver.library.yale.edu/" + coll_id + "a/b/15000.jpg")
        if len(image_URLs)>0:
            print(f"    Added {len(image_URLs)} direct image URLS.")
        r["Direct Image URLs"] = ",".join(image_URLs)
    else:
        print("    Couldn't find thumbnails div. Is this a non-Yale listing?")
# Out:
# Fetching http://hdl.handle.net/10079/digcoll/2771868 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771859 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771675 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771672 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771446 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771269 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771356 ... done.
#     Added 6 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771547 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771447 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771449 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771363 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771438 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771429 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771767 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771680 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771685 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771671 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771546 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771444 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771456 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771454 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771443 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771870 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771754 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771662 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771674 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771541 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771537 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771677 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771451 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771772 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771459 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771267 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771668 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771431 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771452 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771683 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771854 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771521 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771437 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771440 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771682 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771519 ... done.
#     Added 10 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771526 ... done.
# Fetching http://hdl.handle.net/10079/digcoll/2771532 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771856 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771520 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771769 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771448 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771525 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771865 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771862 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771863 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771689 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771850 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771691 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771663 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771762 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771527 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771660 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771872 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771773 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771786 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771686 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771658 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771666 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771860 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771455 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771524 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771756 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771531 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771759 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771779 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771664 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771659 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771543 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771522 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771693 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771667 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771876 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771757 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771684 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771926 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771670 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771874 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771681 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771785 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771780 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771763 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771679 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771673 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771930 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771758 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771776 ... done.
#     Added 2 direct image URLS.
# Fetching http://wwwapp.cc.columbia.edu/ldpd/app/apis/item?mode=item&key=yale.apis.3100270000 ... done.
#     Couldn't find thumbnails div. Is this a non-Yale listing?
# Fetching http://hdl.handle.net/10079/digcoll/2771692 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771867 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771678 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771932 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771450 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771924 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771768 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771761 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771928 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771269 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771447 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771449 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771438 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771429 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771690 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771864 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771767 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771680 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771685 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771671 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771443 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771674 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771541 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771537 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771677 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771772 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771267 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771440 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771682 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771519 ... done.
#     Added 10 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771526 ... done.
# Fetching http://hdl.handle.net/10079/digcoll/2771856 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771520 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771863 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771762 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771527 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771660 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771872 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771773 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771786 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771658 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771666 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771357 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771441 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771548 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771540 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771779 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771878 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771535 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771857 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771667 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771871 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771536 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771534 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771935 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771781 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771519 ... done.
#     Added 10 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771526 ... done.
# Fetching http://hdl.handle.net/10079/digcoll/2771520 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771663 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771440 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771682 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771532 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771850 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771769 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771525 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771448 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771689 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771862 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771863 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771865 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771683 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771762 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771521 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771856 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771663 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771786 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771773 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771686 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771527 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771658 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771691 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771872 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771666 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771660 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771674 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771541 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771459 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771267 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771677 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771772 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771537 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771451 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771668 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771431 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771452 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771854 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771437 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771449 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771363 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771429 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771456 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771690 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771864 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771662 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771546 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771356 ... done.
#     Added 6 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771675 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771446 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771547 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771672 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771767 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771680 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771671 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771444 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771447 ... done.
#     Added 4 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771438 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771685 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771443 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771870 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771454 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771269 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771754 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771524 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771433 ... done.
#     Added 8 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771531 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771759 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771522 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771693 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771779 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771756 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771667 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771878 ... done.
#     Added 1 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771664 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771659 ... done.
#     Added 2 direct image URLS.
# Fetching http://hdl.handle.net/10079/digcoll/2771871 ... done.
#     Added 2 direct image URLS.

# %% [markdown]
# And store them to a file:

# %%
with open("catalog.tsv", "w") as f:
    f.write("\t".join(row_dicts[0].keys()) + "\n")
    for r in row_dicts:
        for k in row_dicts[0].keys():
            if k not in r:
                r[k] = "None"
        f.write("\t".join([r[k] for k in row_dicts[0].keys()]) + "\n")

# %% [markdown]
# Now that we have a bunch of image URLs, we need to download the actual images and organize them on our filesystem.
#
# **Note: if you have a `catalog.tsv` file, you can just resume from here without running the scraping.**

# %%
row_dicts = []
with open("catalog.tsv", "r") as f:
    keys = next(f).strip().split("\t")
    for l in f:
        r = {}
        values = l.strip().split("\t")
        for k, v in zip(keys, values):
            r[k] = v
        
        row_dicts.append(r)

# %% [markdown]
# Let's check if we can use the artifact IDs as unique identifiers in our system:

# %%
ids_seen = []
for r in row_dicts:
    id_nospaces = r["Main identifier"].replace(" ", "_")
    if id_nospaces not in ids_seen:
        ids_seen.append(id_nospaces)
    else:
        print("Error: found duplicate ID " + id_nospaces)

print(f"Found {len(ids_seen)} unique IDs for {len(row_dicts)} items. Storing in dict.")
for i in range(len(row_dicts)):
    row_dicts[i]["Filesystem identifier"] = row_dicts[i]["Main identifier"].replace(" ", "_")
# Out:
# Found 231 unique IDs for 231 items. Storing in dict.

# %% [markdown]
# And now we download all the files, cataloging them by the identifiers we've generated:

# %%
def mkdir(path):
    if not os.path.exists(path):
        os.mkdir(path)
    return path

mkdir("./images")
for in row_dicts:
    papyrus_dir = mkdir("./images/" + r["Filesystem identifier"])
    if "Direct image URLs" not in r:
        print(f"No image links for {papyrus_dir}, skipping.")
        continue
        
    image_urls = r["Direct image URLs"].split(",")
    num_pairs = math.ceil(len(image_urls)/2)
    
    for i, url in enumerate(image_urls):
        pair_dir = mkdir(papyrus_dir + f"/{int(i/2)+1:02}")
        file_name = pair_dir + "/" + ("front.jpg" if (i%2==0) else "back.jpg")
        if os.path.exists(file_name):
            print(f"Skipping {file_name}")
            continue
        print(f"Fetching {file_name} ... ", end="", flush=True)
        img_data = requests.get(url).content
        with open(file_name, 'wb') as f:
            f.write(img_data)
        print("done.")
# Out:
# Skipping ./images/basp_56_100/01/front.jpg
# Skipping ./images/basp_56_100/01/back.jpg
# Skipping ./images/chla_6_310/01/front.jpg
# Skipping ./images/chla_6_310/01/back.jpg
# Skipping ./images/chla_6_311/01/front.jpg
# Skipping ./images/chla_6_311/01/back.jpg
# Skipping ./images/chla_6_312/01/front.jpg
# Skipping ./images/chla_6_312/01/back.jpg
# Skipping ./images/chla_6_313/01/front.jpg
# Skipping ./images/chla_6_314/01/front.jpg
# Skipping ./images/chla_6_314/01/back.jpg
# Skipping ./images/chla_6_315/01/front.jpg
# Skipping ./images/chla_6_315/01/back.jpg
# Skipping ./images/chla_6_315/02/front.jpg
# Skipping ./images/chla_6_315/02/back.jpg
# Skipping ./images/chla_6_315/03/front.jpg
# Skipping ./images/chla_6_315/03/back.jpg
# Skipping ./images/chla_6_316/01/front.jpg
# Skipping ./images/chla_6_316/01/back.jpg
# Skipping ./images/chla_6_316/02/front.jpg
# Skipping ./images/chla_6_316/02/back.jpg
# Skipping ./images/chla_6_317/01/front.jpg
# Skipping ./images/chla_6_317/01/back.jpg
# Skipping ./images/chla_6_317/02/front.jpg
# Skipping ./images/chla_6_317/02/back.jpg
# Skipping ./images/chla_6_318/01/front.jpg
# Skipping ./images/chla_6_319/01/front.jpg
# Skipping ./images/chla_6_319/01/back.jpg
# Fetching ./images/p.dura_129/01/back.jpg ... done.
# Fetching ./images/p.dura_132/01/front.jpg ... done.
# Fetching ./images/p.dura_132/01/back.jpg ... done.
# Fetching ./images/p.dura_136/01/front.jpg ... done.
# Fetching ./images/p.dura_136/01/back.jpg ... done.
# Fetching ./images/p.dura_137/01/front.jpg ... done.
# Fetching ./images/p.dura_141/01/front.jpg ... done.
# Fetching ./images/p.dura_144/01/front.jpg ... done.
# Fetching ./images/p.dura_144/01/back.jpg ... done.
# Fetching ./images/p.dura_145/01/front.jpg ... done.
# Fetching ./images/p.dura_145/01/back.jpg ... done.
# Fetching ./images/p.dura_146/01/front.jpg ... done.
# Fetching ./images/p.dura_146/01/back.jpg ... done.
# Fetching ./images/p.dura_147/01/front.jpg ... done.
# Fetching ./images/p.dura_147/01/back.jpg ... done.
# Fetching ./images/p.dura_148/01/front.jpg ... done.
# Fetching ./images/p.dura_148/01/back.jpg ... done.
# Fetching ./images/p.dura_149/01/front.jpg ... done.
# Fetching ./images/p.dura_149/01/back.jpg ... done.
# Fetching ./images/p.dura_150/01/front.jpg ... done.
# Fetching ./images/p.dura_150/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/03/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/03/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/04/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/04/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/05/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_1/05/back.jpg ... done.
# No image links for ./images/rom.mil.rec_1_2, skipping.
# Fetching ./images/rom.mil.rec_1_3/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_4/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_6/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_6/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_7/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_7/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_8/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_8/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_12/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_13/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_14/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_15/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_16/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_16/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_17/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_17/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_18/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_18/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_19/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_19/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_22/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_23/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_25/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_25/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_26/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_27/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_29/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_31/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_32/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_32/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_33/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_35/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_41/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_42/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_42/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_43/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_44/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_47/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_48/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_49/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_49/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_50/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_50/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_54/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_55/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_56/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_57/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_57/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_60/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_61/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_62/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_62/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_66/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_83/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_88/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_91/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_91/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_91/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_91/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_92/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_92/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_93/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_93/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_94/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_95/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_96/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_97/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_97/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/03/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_98/03/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_99/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_99/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_100/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_101/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_101/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_101/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_101/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_103/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_103/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_104/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_104/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_105/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_105/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_106/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_106/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_107/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_107/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_108/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_108/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_108/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_108/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_109/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_109/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_110/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_110/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_111/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_111/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_112/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_112/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_113/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_113/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_114/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_114/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_115/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_115/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_116/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_116/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/02/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/02/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/03/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/03/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/04/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_117/04/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_118/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_118/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_119/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_119/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_120/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_121/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_121/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_122/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_122/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_123/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_123/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_124/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_124/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_125/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_126/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_126/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_127/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_127/01/back.jpg ... done.
# Fetching ./images/rom.mil.rec_1_128/01/front.jpg ... done.
# Fetching ./images/rom.mil.rec_1_128/01/back.jpg ... done.

# %% [markdown]
# And write out to a file once more, so we have the filesystem IDs in the table too.

# %%
with open("catalog.tsv", "w") as f:
    f.write("\t".join(row_dicts[0].keys()) + "\n")
    for r in row_dicts:
        for k in row_dicts[0].keys():
            if k not in r:
                r[k] = "None"
        f.write("\t".join([r[k] for k in row_dicts[0].keys()]) + "\n")
